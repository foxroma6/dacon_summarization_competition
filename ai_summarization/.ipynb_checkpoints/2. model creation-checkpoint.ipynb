# %%
from transformers import pipeline

# %%
summarization= pipeline("summarization")
# Out:
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=1621.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=898822.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=456318.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=26.0), HTML(value='')))
# HBox(children=(HTML(value='Downloading'), FloatProgress(value=0.0, max=1222317369.0), HTML(value='')))

# %%
original_text="""
사회적 거리두기 2단계 적용 지역에선 유흥시설 5종은 집합금지가 이뤄진다. 방문판매 등 직접판매홍보관은 4㎡에서 8㎡ 당 1명으로 인원 제한이 강화된다. 노래연습장은 오후 9시 이후 영업이 중단된다. 50㎡ 이상의 일반음식점, 휴게음식점, 제과점에 대해선 카페는 전 시간 포장·배달만 허용하고 음식점은 오후 9시 이후엔 식당 내 식사를 금지한다.
헬스장 등 실내체육시설은 오후 9시부터 운영을 중단한다. 놀이공원이나 워터파크는 수용 가능 인원의 3분의 1로 운영 규모를 줄인다. 국공립시설 중 경마 정륜 경정 카지노는 운영을 중단하고 이외 시설은 30% 이내로 제한한다. 스포츠 관람은 수용 가능 인원의 10%만 입장을 허용한다. 예배나 법회 등 종교활동도 좌석 수의 20%로 줄여야 한다."""

# %%
summary_text= summarization(original_text)[0]['summary_text']

# %%
summary_text
# Out:
# '   \xa0- \xa0pronounced: \xa0\xa0-\xa0‘. ‘.’ – \xa0“. “.” ‘”�   “”�  ”.  ‘ż�”: “\xa0”“  . ”” –   .   –  ”.“ “ń” -   이’: ‘I’m not sure what’s going to happen next.   I’ll be able to get back in touch with the world now. I�'
